-- %%
-- Display all columns and rows from the Customers table
SELECT * FROM `workspace`.`default`.customers_cvs;

-- Display all columns and rows from the Products table
SELECT * FROM `workspace`.`default`.`products_cvs`
