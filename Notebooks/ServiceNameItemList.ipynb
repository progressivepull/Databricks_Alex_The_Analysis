-- %% [markdown]
-- # Description
-- The system.access.audit table records every audited action across Databricks.
-- service_name tells you which internal Databricks service generated each audit event.
--
-- Running this query gives you a clean inventory of all services producing audit logs in your workspace or account.

-- %%
SELECT DISTINCT `service_name`
FROM `system`.`access`.`audit`
ORDER BY `service_name`;
