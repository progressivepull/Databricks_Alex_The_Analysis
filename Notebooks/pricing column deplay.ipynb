-- %% [markdown]
-- To provide the pricing details for the account with ID 6ce7b368-ca17-4fd5-a2b2-620d95800f5d, we will need to query the system.billing.list_prices table to retrieve the pricing information. Below is the SQL query that will display the necessary pricing details for the specified account ID.

-- %%
SELECT `price_start_time`, `price_end_time`, `sku_name`, `cloud`, `currency_code`, `usage_unit`, `pricing`.`default`, `pricing`.`promotional`.`default`, `pricing`.`effective_list`.`default`
FROM `system`.`billing`.`list_prices`
WHERE `account_id` = '6ce7b368-ca17-4fd5-a2b2-620d95800f5d';
